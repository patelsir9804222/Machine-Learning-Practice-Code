# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("Data/titanic.csv")

# %%
data.shape
# Out:
# (891, 12)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.utils import shuffle
data = shuffle(data, random_state = 42)
div = int(data.shape[0]/4)
train = data.loc[:3*div+1,:]
test = data.loc[3*div+1:]
train.shape, test.shape
# Out:
# ((621, 12), (271, 12))

# %%
train.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 709          710         1       3
# 439          440         0       2
# 840          841         0       3
# 720          721         1       2
# 39            40         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
# 439             Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 709      1              2661  15.2458   NaN        C
# 439      0        C.A. 18723  10.5000   NaN        S
# 840      0  SOTON/O2 3101287   7.9250   NaN        S
# 720      1            248727  33.0000   NaN        S
# 39       0              2651  11.2417   NaN        C

# %%
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 667          668         0       3
# 571          572         1       1
# 636          637         0       3
# 714          715         0       2
# 262          263         0       1
#
#                                               Name     Sex   Age  SibSp  \
# 667                     Rommetvedt, Mr. Knud Paust    male   NaN      0
# 571  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 636                     Leinonen, Mr. Antti Gustaf    male  32.0      0
# 714                          Greenberg, Mr. Samuel    male  52.0      0
# 262                              Taussig, Mr. Emil    male  52.0      1
#
#      Parch             Ticket     Fare Cabin Embarked
# 667      0             312993   7.7750   NaN        S
# 571      0              11769  51.4792  C101        S
# 636      0  STON/O 2. 3101292   7.9250   NaN        S
# 714      0             250647  13.0000   NaN        S
# 262      1             110413  79.6500   E67        S

# %%
test['simple_mode'] = train['Survived'].mode()[0]
test['simple_mode'].head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\680694993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['simple_mode'] = train['Survived'].mode()[0]
# 667    0
# 571    0
# 636    0
# 714    0
# 262    0
# Name: simple_mode, dtype: int64

# %%
from sklearn.utils import shuffle
data = shuffle(data, random_state = 42)
div = int(data.shape[0]/4)
train = data.loc[:3*div+1,:]
test = data.loc[3*div+1:]

train.shape, test.shape
# Out:
# ((36, 12), (856, 12))

# %%
train.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 878          879         0       3               Laleff, Mr. Kristo    male
# 277          278         0       2      Parkes, Mr. Francis "Frank"    male
# 504          505         1       1            Maioni, Miss. Roberta  female
# 242          243         0       2  Coleridge, Mr. Reginald Charles    male
# 739          740         0       3               Nankoff, Mr. Minko    male
#
#       Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 878   NaN      0      0       349217   7.8958   NaN        S
# 277   NaN      0      0       239853   0.0000   NaN        S
# 504  16.0      0      0       110152  86.5000   B79        S
# 242  29.0      0      0  W./C. 14263  10.5000   NaN        S
# 739   NaN      0      0       349218   7.8958   NaN        S

# %%
test.head()
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 667          668         0       3                 Rommetvedt, Mr. Knud Paust
# 682          683         0       3                Olsvigen, Mr. Thor Anderson
# 781          782         1       1  Dick, Mrs. Albert Adrian (Vera Gillespie)
# 243          244         0       3              Maenpaa, Mr. Matti Alexanteri
# 206          207         0       3                 Backstrom, Mr. Karl Alfred
#
#         Sex   Age  SibSp  Parch             Ticket    Fare Cabin Embarked
# 667    male   NaN      0      0             312993   7.775   NaN        S
# 682    male  20.0      0      0               6563   9.225   NaN        S
# 781  female  17.0      1      0              17474  57.000   B20        S
# 243    male  22.0      0      0  STON/O 2. 3101275   7.125   NaN        S
# 206    male  32.0      1      0            3101278  15.850   NaN        S

# %%
test['sample_mode']=train['Survived'].mode()[0]
test['sample_mode'].head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\3992551260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sample_mode']=train['Survived'].mode()[0]
# 667    0
# 682    0
# 781    0
# 243    0
# 206    0
# Name: sample_mode, dtype: int64

# %%
sample_mode_accuracy = accuracy_score(test['Survived'], test['sample_mode'])
sample_mode_accuracy
# Out:
# 0.616822429906542

# %%
gender_mode = pd.crosstab(train['Survived'],train['Sex'])
gender_mode
# Out:
# Sex       female  male
# Survived
# 0              2    20
# 1             11     3

# %%
test['gender_mode'] = test['Survived']

# for every unique value in column
for i in test['Sex'].unique():
  # Calculate and Assign mode to new column, corresponding to unique values in "Sex"
  test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gender_mode'] = test['Survived']
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2040\248540814.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gender_mode'][test['Sex'] == str(i)] = train['Survived'][train['Sex'] == str(i)].mode()[0]
