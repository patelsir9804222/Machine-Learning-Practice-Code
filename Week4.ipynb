# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Overview of Subsetting in Pandas 📍 📍</h1></center>
#
#
#
# ---
#
# #### `TABLE OF CONTENTS`
#
# - What is an index?
# - How to subset first N rows based on their position index?
# - Can we change the index?
# - Will the index be always numeric?
# - How to subset the data based on a label of the index?
# - Can we reset the index?
# - How to subset the data based on a value of a column?
#
# ---
#
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.head(7)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528

# %% [markdown]
# ---
#
# #### `CAN WE CHANGE THE INDEX?`
#
# ---
#
# ***The answer is `Yes`. We can change the index. Let's see how?***
#
# ---

# %% [markdown]
# #### Create a random list of 8523 numbers and set it as the index
# ---

# %%
import random

# %%
random_list=[random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# [3158,
#  2052,
#  4529,
#  7127,
#  5042,
#  1523,
#  6036,
#  8175,
#  5153,
#  2908,
#  5101,
#  4080,
#  8095,
#  5149,
#  8146,
#  2207,
#  5298,
#  5459,
#  833,
#  1800,
#  4036,
#  6022,
#  5706,
#  8269,
#  5830,
#  1520,
#  2069,
#  7901,
#  3019,
#  2036,
#  4305,
#  8222,
#  1449,
#  3450,
#  4152,
#  6146,
#  6794,
#  6654,
#  2112,
#  6627,
#  4221,
#  2571,
#  3450,
#  5513,
#  5381,
#  8469,
#  1830,
#  2746,
#  1457,
#  7994,
#  3156,
#  7141,
#  8475,
#  2697,
#  3076,
#  7227,
#  463,
#  350,
#  3295,
#  3571,
#  2439,
#  8337,
#  5039,
#  4127,
#  1862,
#  5833,
#  2213,
#  2226,
#  311,
#  3735,
#  4927,
#  1086,
#  2992,
#  577,
#  6230,
#  439,
#  2988,
#  5590,
#  2136,
#  2335,
#  7199,
#  6022,
#  7579,
#  8069,
#  3293,
#  5643,
#  6063,
#  15,
#  6008,
#  5056,
#  4428,
#  1395,
#  5517,
#  5117,
#  633,
#  3269,
#  6272,
#  136,
#  1814,
#  7884,
#  8076,
#  1857,
#  3373,
#  1692,
#  7094,
#  7338,
#  4198,
#  1416,
#  914,
#  6464,
#  7630,
#  1003,
#  5274,
#  375,
#  5875,
#  781,
#  4566,
#  2192,
#  7765,
#  812,
#  4347,
#  4512,
#  4882,
#  5682,
#  466,
#  6461,
#  6064,
#  7218,
#  3577,
#  4404,
#  2855,
#  1894,
#  5125,
#  7866,
#  783,
#  5988,
#  6320,
#  286,
#  5394,
#  6911,
#  6214,
#  1796,
#  4355,
#  1970,
#  3128,
#  5580,
#  3052,
#  5487,
#  2018,
#  5702,
#  208,
#  7065,
#  6416,
#  7503,
#  6849,
#  8156,
#  4247,
#  1515,
#  273,
#  4182,
#  7431,
#  3000,
#  5710,
#  7686,
#  408,
#  8393,
#  2185,
#  6730,
#  1193,
#  3536,
#  3962,
#  8081,
#  3553,
#  1022,
#  1625,
#  5928,
#  6333,
#  3969,
#  7654,
#  1734,
#  4404,
#  8208,
#  7607,
#  6201,
#  6268,
#  3190,
#  752,
#  2315,
#  3005,
#  1437,
#  6047,
#  5896,
#  30,
#  1730,
#  103,
#  6159,
#  772,
#  5152,
#  4911,
#  3521,
#  3163,
#  879,
#  7287,
#  2192,
#  6087,
#  8208,
#  5087,
#  4784,
#  4974,
#  4602,
#  4219,
#  5085,
#  4708,
#  7082,
#  8480,
#  2876,
#  6863,
#  6476,
#  1688,
#  83,
#  478,
#  1566,
#  4150,
#  5532,
#  5589,
#  3641,
#  6674,
#  7520,
#  4051,
#  1207,
#  7454,
#  4517,
#  9,
#  6666,
#  4212,
#  4379,
#  8072,
#  5576,
#  4299,
#  7333,
#  6858,
#  5303,
#  5449,
#  7137,
#  787,
#  1664,
#  6609,
#  6767,
#  4281,
#  7658,
#  5810,
#  1988,
#  6967,
#  995,
#  4202,
#  5831,
#  491,
#  5282,
#  4844,
#  8389,
#  3393,
#  7861,
#  7872,
#  1650,
#  7047,
#  6636,
#  6347,
#  5329,
#  6097,
#  1139,
#  1574,
#  6895,
#  6979,
#  4537,
#  6927,
#  795,
#  6624,
#  8478,
#  6093,
#  2710,
#  23,
#  8428,
#  5976,
#  3164,
#  8068,
#  1309,
#  3743,
#  4026,
#  426,
#  3033,
#  300,
#  5076,
#  283,
#  4325,
#  5909,
#  3372,
#  1030,
#  5188,
#  5352,
#  5348,
#  4437,
#  7636,
#  5904,
#  4702,
#  4361,
#  2723,
#  1221,
#  6497,
#  3795,
#  1013,
#  7374,
#  599,
#  2775,
#  924,
#  5373,
#  6275,
#  5844,
#  8006,
#  1071,
#  383,
#  4193,
#  6855,
#  3892,
#  5114,
#  2430,
#  2860,
#  6227,
#  397,
#  2057,
#  5982,
#  3760,
#  5291,
#  5035,
#  4889,
#  3540,
#  6719,
#  2587,
#  4279,
#  1061,
#  1001,
#  7210,
#  758,
#  2251,
#  1234,
#  2401,
#  3911,
#  1351,
#  5127,
#  7238,
#  3974,
#  3589,
#  6714,
#  5008,
#  2691,
#  2301,
#  4551,
#  3367,
#  1700,
#  7324,
#  2186,
#  4754,
#  4206,
#  1020,
#  8267,
#  4867,
#  660,
#  8122,
#  8476,
#  3973,
#  5435,
#  6473,
#  2182,
#  5299,
#  597,
#  7553,
#  7279,
#  1500,
#  5362,
#  7231,
#  1184,
#  2299,
#  7496,
#  7475,
#  3789,
#  2881,
#  2258,
#  1039,
#  2529,
#  3884,
#  2613,
#  7296,
#  5054,
#  7362,
#  5880,
#  1061,
#  7676,
#  275,
#  618,
#  6553,
#  1636,
#  4197,
#  5822,
#  168,
#  2912,
#  1181,
#  1812,
#  5946,
#  122,
#  3975,
#  3743,
#  2111,
#  5847,
#  879,
#  6123,
#  3921,
#  6429,
#  4785,
#  1019,
#  395,
#  7884,
#  7037,
#  8123,
#  3573,
#  8424,
#  1978,
#  6404,
#  1405,
#  6973,
#  3369,
#  3724,
#  4540,
#  8267,
#  2018,
#  762,
#  1612,
#  6669,
#  8384,
#  4553,
#  2952,
#  838,
#  5931,
#  1017,
#  5936,
#  7722,
#  79,
#  2756,
#  1741,
#  142,
#  6231,
#  6210,
#  234,
#  8121,
#  199,
#  3705,
#  3046,
#  4957,
#  6324,
#  6901,
#  5545,
#  7094,
#  1585,
#  4607,
#  7702,
#  4053,
#  5247,
#  7828,
#  6487,
#  4407,
#  1398,
#  3106,
#  3072,
#  6763,
#  7080,
#  7055,
#  3241,
#  1101,
#  987,
#  430,
#  5413,
#  7669,
#  8053,
#  2016,
#  2881,
#  5064,
#  6514,
#  3253,
#  7741,
#  5828,
#  8372,
#  7245,
#  5414,
#  4715,
#  5986,
#  3493,
#  14,
#  1483,
#  7073,
#  7450,
#  7327,
#  403,
#  3137,
#  575,
#  22,
#  1987,
#  7526,
#  7198,
#  2333,
#  2708,
#  2726,
#  1129,
#  5640,
#  8269,
#  266,
#  2368,
#  7937,
#  4477,
#  8199,
#  2349,
#  198,
#  2930,
#  2174,
#  7962,
#  1132,
#  7817,
#  971,
#  1028,
#  3701,
#  431,
#  388,
#  7375,
#  5096,
#  4108,
#  4279,
#  8291,
#  5326,
#  5920,
#  520,
#  7771,
#  3255,
#  528,
#  7772,
#  8478,
#  5716,
#  3595,
#  2417,
#  225,
#  2833,
#  8414,
#  846,
#  1138,
#  751,
#  4558,
#  5569,
#  2718,
#  7668,
#  4330,
#  5202,
#  8179,
#  1650,
#  1572,
#  1488,
#  5756,
#  7888,
#  4126,
#  6382,
#  6604,
#  5392,
#  3785,
#  5342,
#  7959,
#  2,
#  2789,
#  7947,
#  4509,
#  8013,
#  940,
#  6643,
#  46,
#  1568,
#  4081,
#  174,
#  2037,
#  5192,
#  4855,
#  5185,
#  5005,
#  6631,
#  7564,
#  6944,
#  6298,
#  8239,
#  5883,
#  6301,
#  2201,
#  7782,
#  6816,
#  2113,
#  7181,
#  684,
#  2113,
#  3534,
#  2049,
#  1384,
#  3943,
#  3514,
#  6247,
#  6939,
#  6026,
#  6272,
#  3697,
#  895,
#  6824,
#  2866,
#  3045,
#  4595,
#  7742,
#  2818,
#  2005,
#  8085,
#  7709,
#  4810,
#  4252,
#  3911,
#  4590,
#  4400,
#  1705,
#  4974,
#  6377,
#  2846,
#  743,
#  2256,
#  112,
#  6594,
#  1777,
#  4275,
#  5333,
#  3680,
#  1230,
#  99,
#  4094,
#  2889,
#  2837,
#  7595,
#  2782,
#  3804,
#  5333,
#  4476,
#  1807,
#  4942,
#  5078,
#  5026,
#  6282,
#  5091,
#  7256,
#  6254,
#  6545,
#  6245,
#  7347,
#  2159,
#  5109,
#  1387,
#  2575,
#  6397,
#  5256,
#  2331,
#  6455,
#  103,
#  4056,
#  8230,
#  7970,
#  6669,
#  3520,
#  6276,
#  3933,
#  1734,
#  4674,
#  3057,
#  354,
#  8355,
#  8441,
#  2083,
#  359,
#  2176,
#  3774,
#  2240,
#  6063,
#  331,
#  6850,
#  4500,
#  3731,
#  5715,
#  341,
#  2266,
#  5414,
#  7221,
#  766,
#  262,
#  7654,
#  2945,
#  5459,
#  8346,
#  5857,
#  6025,
#  3932,
#  2034,
#  1427,
#  6495,
#  8070,
#  3051,
#  8063,
#  3943,
#  2772,
#  77,
#  5646,
#  2991,
#  3547,
#  1317,
#  490,
#  7674,
#  1129,
#  4375,
#  7093,
#  7250,
#  8224,
#  4315,
#  5716,
#  3775,
#  6232,
#  2866,
#  2263,
#  6962,
#  19,
#  1656,
#  6781,
#  5701,
#  4866,
#  907,
#  3873,
#  2774,
#  3523,
#  3629,
#  3748,
#  663,
#  1233,
#  3912,
#  2510,
#  540,
#  4682,
#  1518,
#  2780,
#  6531,
#  297,
#  8108,
#  6449,
#  457,
#  2543,
#  3029,
#  5216,
#  6826,
#  6179,
#  7919,
#  5182,
#  507,
#  4725,
#  851,
#  6818,
#  8404,
#  129,
#  2039,
#  3357,
#  3612,
#  1270,
#  409,
#  3919,
#  7770,
#  4153,
#  5842,
#  4910,
#  1138,
#  2917,
#  13,
#  7128,
#  5052,
#  5501,
#  1615,
#  5660,
#  2986,
#  5929,
#  8307,
#  1075,
#  256,
#  936,
#  3067,
#  2043,
#  6771,
#  1819,
#  7485,
#  1805,
#  5183,
#  7090,
#  2406,
#  8423,
#  833,
#  4803,
#  1936,
#  5646,
#  2184,
#  8057,
#  7397,
#  5385,
#  2241,
#  4566,
#  4589,
#  6904,
#  7225,
#  7017,
#  1247,
#  3846,
#  5384,
#  1160,
#  4541,
#  277,
#  4352,
#  5146,
#  2575,
#  4881,
#  8213,
#  4718,
#  6621,
#  2461,
#  4957,
#  890,
#  2663,
#  3952,
#  4982,
#  3599,
#  4831,
#  4837,
#  1334,
#  6815,
#  2299,
#  1769,
#  5933,
#  4175,
#  2775,
#  1503,
#  1945,
#  3792,
#  3426,
#  6369,
#  5743,
#  6415,
#  7165,
#  5041,
#  6616,
#  6479,
#  4608,
#  7739,
#  6141,
#  6906,
#  8446,
#  679,
#  4335,
#  7247,
#  3895,
#  2824,
#  2827,
#  1496,
#  4967,
#  6982,
#  2914,
#  6491,
#  8384,
#  4534,
#  327,
#  5334,
#  2505,
#  1811,
#  4860,
#  1500,
#  2334,
#  1207,
#  1465,
#  7411,
#  7380,
#  4830,
#  1009,
#  4490,
#  1459,
#  4192,
#  68,
#  1318,
#  6560,
#  7800,
#  6471,
#  5792,
#  2154,
#  5084,
#  4274,
#  4683,
#  332,
#  689,
#  2642,
#  5888,
#  3616,
#  2439,
#  2865,
#  7788,
#  3582,
#  71,
#  3333,
#  3725,
#  2697,
#  2097,
#  8415,
#  7570,
#  440,
#  6689,
#  6291,
#  8038,
#  2529,
#  6525,
#  6598,
#  6510,
#  8007,
#  1049,
#  1786,
#  8042,
#  7022,
#  7499,
#  7616,
#  6776,
#  2804,
#  7290,
#  7090,
#  1247,
#  50,
#  1449,
#  2353,
#  5262,
#  3382,
#  8193,
#  2301,
#  1405,
#  6741,
#  6601,
#  1876,
#  7117,
#  284,
#  5434,
#  7531,
#  2750,
#  6913,
#  3475,
#  6597,
#  607,
#  3892,
#  8290,
#  3487,
#  6159,
#  1221,
#  7139,
#  2229,
#  2358,
#  923,
#  1780,
#  90,
#  6162,
#  509,
#  2661,
#  6285,
#  1915,
#  2890,
#  235,
#  6287,
#  5262,
#  1083,
#  6503,
#  8043,
#  7431,
#  5604,
#  343,
#  4025,
#  174,
#  634,
#  4723,
#  4928,
#  2272,
#  4039,
#  564,
#  1752,
#  3931,
#  4848,
#  28,
#  2715,
#  1235,
#  6104,
#  1448,
#  7890,
#  3496,
#  ...]

# %%
random.indsex=random_list

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.set_index('Item_MRP', drop=True, inplace=True)

# %%
data.head()
# Out:
#          Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_MRP
# 249.8092           FDA15         9.30          Low Fat         0.016047
# 48.2692            DRC01         5.92          Regular         0.019278
# 141.6180           FDN15        17.50          Low Fat         0.016760
# 182.0950           FDX07        19.20          Regular         0.000000
# 53.8614            NCD19         8.93          Low Fat         0.000000
#
#                       Item_Type Outlet_Identifier  Outlet_Establishment_Year  \
# Item_MRP
# 249.8092                  Dairy            OUT049                       1999
# 48.2692             Soft Drinks            OUT018                       2009
# 141.6180                   Meat            OUT049                       1999
# 182.0950  Fruits and Vegetables            OUT010                       1998
# 53.8614               Household            OUT013                       1987
#
#          Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_MRP
# 249.8092      Medium               Tier 1  Supermarket Type1
# 48.2692       Medium               Tier 3  Supermarket Type2
# 141.6180      Medium               Tier 1  Supermarket Type1
# 182.0950         NaN               Tier 3      Grocery Store
# 53.8614         High               Tier 3  Supermarket Type1
#
#           Item_Outlet_Sales
# Item_MRP
# 249.8092          3735.1380
# 48.2692            443.4228
# 141.6180          2097.2700
# 182.0950           732.3800
# 53.8614            994.7052

# %%
data.index
# Out:
# Index([249.8092,  48.2692,  141.618,  182.095,  53.8614,  51.4008,  57.6588,
#        107.7622,  96.9726, 187.8214,
#        ...
#         99.9042,  57.5904, 157.5288,  58.7588, 178.8318, 214.5218,  108.157,
#         85.1224, 103.1332,   75.467],
#       dtype='float64', name='Item_MRP', length=8523)

# %%
data.set_index('Outlet_Identifier', drop=True, inplace=True)

# %%
data.head()
# Out:
#                   Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Identifier
# OUT049                      FDA15         9.30          Low Fat
# OUT018                      DRC01         5.92          Regular
# OUT049                      FDN15        17.50          Low Fat
# OUT010                      FDX07        19.20          Regular
# OUT013                      NCD19         8.93          Low Fat
#
#                    Item_Visibility              Item_Type  \
# Outlet_Identifier
# OUT049                    0.016047                  Dairy
# OUT018                    0.019278            Soft Drinks
# OUT049                    0.016760                   Meat
# OUT010                    0.000000  Fruits and Vegetables
# OUT013                    0.000000              Household
#
#                    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Outlet_Identifier
# OUT049                                  1999      Medium               Tier 1
# OUT018                                  2009      Medium               Tier 3
# OUT049                                  1999      Medium               Tier 1
# OUT010                                  1998         NaN               Tier 3
# OUT013                                  1987        High               Tier 3
#
#                          Outlet_Type  Item_Outlet_Sales
# Outlet_Identifier
# OUT049             Supermarket Type1          3735.1380
# OUT018             Supermarket Type2           443.4228
# OUT049             Supermarket Type1          2097.2700
# OUT010                 Grocery Store           732.3800
# OUT013             Supermarket Type1           994.7052

# %%
data.index
# Out:
# Index(['OUT049', 'OUT018', 'OUT049', 'OUT010', 'OUT013', 'OUT018', 'OUT013',
#        'OUT027', 'OUT045', 'OUT017',
#        ...
#        'OUT035', 'OUT045', 'OUT018', 'OUT018', 'OUT046', 'OUT013', 'OUT045',
#        'OUT035', 'OUT018', 'OUT046'],
#       dtype='object', name='Outlet_Identifier', length=8523)

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#                   Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Identifier
# OUT049                      FDA15        9.300          Low Fat
# OUT046                      FDA03       18.500          Regular
# OUT035                      FDU02       13.350          Low Fat
# OUT010                      FDE51        5.925          Regular
# OUT010                      FDV38       19.250          Low Fat
# ...                           ...          ...              ...
# OUT035                      FDC39        7.405          Low Fat
# OUT017                      FDS26       20.350          Low Fat
# OUT018                      FDV50       14.300          Low Fat
# OUT035                      FDY50        5.800          Low Fat
# OUT013                      FDR26       20.700          Low Fat
#
#                    Item_Visibility Item_Type  Outlet_Establishment_Year  \
# Outlet_Identifier
# OUT049                    0.016047     Dairy                       1999
# OUT046                    0.045464     Dairy                       1997
# OUT035                    0.102492     Dairy                       2004
# OUT010                    0.161467     Dairy                       1998
# OUT010                    0.170349     Dairy                       1998
# ...                            ...       ...                        ...
# OUT035                    0.159165     Dairy                       2004
# OUT017                    0.089975     Dairy                       2007
# OUT018                    0.123071     Dairy                       2009
# OUT035                    0.130931     Dairy                       2004
# OUT013                    0.042801     Dairy                       1987
#
#                   Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Outlet_Identifier
# OUT049                 Medium               Tier 1  Supermarket Type1
# OUT046                  Small               Tier 1  Supermarket Type1
# OUT035                  Small               Tier 2  Supermarket Type1
# OUT010                    NaN               Tier 3      Grocery Store
# OUT010                    NaN               Tier 3      Grocery Store
# ...                       ...                  ...                ...
# OUT035                  Small               Tier 2  Supermarket Type1
# OUT017                    NaN               Tier 2  Supermarket Type1
# OUT018                 Medium               Tier 3  Supermarket Type2
# OUT035                  Small               Tier 2  Supermarket Type1
# OUT013                   High               Tier 3  Supermarket Type1
#
#                    Item_Outlet_Sales
# Outlet_Identifier
# OUT049                     3735.1380
# OUT046                     2187.1530
# OUT035                     2748.4224
# OUT010                      178.4344
# OUT010                      163.7868
# ...                              ...
# OUT035                     3739.1328
# OUT017                     7588.1226
# OUT018                     2093.9410
# OUT035                     1516.6924
# OUT013                     2479.4392
#
# [682 rows x 10 columns]

# %%
data[data['Item_Identifier']== 'FDA15']
# Out:
#                   Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Identifier
# OUT049                      FDA15          9.3          Low Fat
# OUT045                      FDA15          9.3          Low Fat
# OUT035                      FDA15          9.3          Low Fat
# OUT018                      FDA15          9.3          Low Fat
# OUT010                      FDA15          9.3          Low Fat
# OUT013                      FDA15          9.3          Low Fat
# OUT027                      FDA15          NaN          Low Fat
# OUT017                      FDA15          9.3               LF
#
#                    Item_Visibility Item_Type  Outlet_Establishment_Year  \
# Outlet_Identifier
# OUT049                    0.016047     Dairy                       1999
# OUT045                    0.016055     Dairy                       2002
# OUT035                    0.016019     Dairy                       2004
# OUT018                    0.016088     Dairy                       2009
# OUT010                    0.026818     Dairy                       1998
# OUT013                    0.016009     Dairy                       1987
# OUT027                    0.015945     Dairy                       1985
# OUT017                    0.016113     Dairy                       2007
#
#                   Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Outlet_Identifier
# OUT049                 Medium               Tier 1  Supermarket Type1
# OUT045                    NaN               Tier 2  Supermarket Type1
# OUT035                  Small               Tier 2  Supermarket Type1
# OUT018                 Medium               Tier 3  Supermarket Type2
# OUT010                    NaN               Tier 3      Grocery Store
# OUT013                   High               Tier 3  Supermarket Type1
# OUT027                 Medium               Tier 3  Supermarket Type3
# OUT017                    NaN               Tier 2  Supermarket Type1
#
#                    Item_Outlet_Sales
# Outlet_Identifier
# OUT049                     3735.1380
# OUT045                     5976.2208
# OUT035                     6474.2392
# OUT018                     5976.2208
# OUT010                      498.0184
# OUT013                     6474.2392
# OUT027                     6474.2392
# OUT017                     5976.2208

# %% [markdown]
# ---
# ---
#
# <center><h1> 📍 📍 Subsetting: Position Based 📍 📍 </h1></center>
#
#
# ---
#
# ### `TABLE OF CONTENTS`
#
# - How to view the top and bottom rows of the data?
# - How to select rows in a particular range?
# - How to select the rows by position?
# - How to select the specific rows and columns from the data using their position?
#
#
# ---
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.
#
# ---

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.tail(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8521  Snack Foods  103.1332            OUT018                       2009
# 8522  Soft Drinks   75.4670            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 8521      Medium               Tier 3  Supermarket Type2          1845.5976
# 8522       Small               Tier 1  Supermarket Type1           765.6700

# %%
data[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# 12                       1999      Medium               Tier 1
# 13                       1997       Small               Tier 1
# 14                       1987        High               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 10  Supermarket Type1          1516.0266
# 11  Supermarket Type1          2187.1530
# 12  Supermarket Type1          1589.2646
# 13  Supermarket Type1          2145.2076
# 14  Supermarket Type1          1977.4260

# %%
data.iloc[[1, 3, 5, 7, 18]]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1            DRC01        5.920          Regular         0.019278
# 3            FDX07       19.200          Regular         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 7            FDP10          NaN          Low Fat         0.127470
# 18           DRI11          NaN          Low Fat         0.034238
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 1             Soft Drinks   48.2692            OUT018
# 3   Fruits and Vegetables  182.0950            OUT010
# 5            Baking Goods   51.4008            OUT018
# 7             Snack Foods  107.7622            OUT027
# 18            Hard Drinks  113.2834            OUT027
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                        2009      Medium               Tier 3
# 3                        1998         NaN               Tier 3
# 5                        2009      Medium               Tier 3
# 7                        1985      Medium               Tier 3
# 18                       1985      Medium               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 1   Supermarket Type2           443.4228
# 3       Grocery Store           732.3800
# 5   Supermarket Type2           556.6088
# 7   Supermarket Type3          4022.7636
# 18  Supermarket Type3          2303.6680

# %%
data.iloc[[1, 2, 3, 4],[4, 3, 7]]
# Out:
#                Item_Type  Item_Visibility  Outlet_Establishment_Year
# 1            Soft Drinks         0.019278                       2009
# 2                   Meat         0.016760                       1999
# 3  Fruits and Vegetables         0.000000                       1998
# 4              Household         0.000000                       1987

# %%
data.iloc[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# 12                       1999      Medium               Tier 1
# 13                       1997       Small               Tier 1
# 14                       1987        High               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 10  Supermarket Type1          1516.0266
# 11  Supermarket Type1          2187.1530
# 12  Supermarket Type1          1589.2646
# 13  Supermarket Type1          2145.2076
# 14  Supermarket Type1          1977.4260

# %%
data.iloc[10:-15]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# 13             FDS46        17.60          Regular         0.047257
# 14             FDF32        16.35          Low Fat         0.068024
# ...              ...          ...              ...              ...
# 8503           FDQ44        20.50          Low Fat         0.036133
# 8504           NCN18          NaN          Low Fat         0.124111
# 8505           FDB46        10.50          Regular         0.094146
# 8506           DRF37        17.25          Low Fat         0.084676
# 8507           FDN28         5.88          Regular         0.030242
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# ...                     ...       ...               ...
# 8503  Fruits and Vegetables  120.1756            OUT035
# 8504              Household  111.7544            OUT027
# 8505            Snack Foods  210.8244            OUT018
# 8506            Soft Drinks  263.1910            OUT018
# 8507           Frozen Foods  101.7990            OUT035
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                         1999      Medium               Tier 1
# 11                         1997       Small               Tier 1
# 12                         1999      Medium               Tier 1
# 13                         1997       Small               Tier 1
# 14                         1987        High               Tier 3
# ...                         ...         ...                  ...
# 8503                       2004       Small               Tier 2
# 8504                       1985      Medium               Tier 3
# 8505                       2009      Medium               Tier 3
# 8506                       2009      Medium               Tier 3
# 8507                       2004       Small               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 10    Supermarket Type1          1516.0266
# 11    Supermarket Type1          2187.1530
# 12    Supermarket Type1          1589.2646
# 13    Supermarket Type1          2145.2076
# 14    Supermarket Type1          1977.4260
# ...                 ...                ...
# 8503  Supermarket Type1          3392.9168
# 8504  Supermarket Type3          4138.6128
# 8505  Supermarket Type2          2117.2440
# 8506  Supermarket Type2          3944.8650
# 8507  Supermarket Type1           515.9950
#
# [8498 rows x 12 columns]

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Subsetting: Label Based 📍 📍</h1></center>
#
# ---
#
#
# ### `TABLE OF CONTENTS`
#
# - How to select rows using the label of the index?
# - Difference between loc and iloc
#
#
# ---
#
# ####  `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.
# ---

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.set_index('Item_Identifier', inplace=True, drop=True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15                                 1999      Medium               Tier 1
# DRC01                                 2009      Medium               Tier 3
# FDN15                                 1999      Medium               Tier 1
# FDX07                                 1998         NaN               Tier 3
# NCD19                                 1987        High               Tier 3
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# DRC01            Supermarket Type2           443.4228
# FDN15            Supermarket Type1          2097.2700
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# FDA15            248.5092            OUT035                       2004
# FDA15            249.6092            OUT018                       2009
# FDA15            248.9092            OUT010                       1998
# FDA15            250.6092            OUT013                       1987
# FDA15            249.5092            OUT027                       1985
# FDA15            248.8092            OUT017                       2007
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                   NaN               Tier 2  Supermarket Type1
# FDA15                 Small               Tier 2  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type2
# FDA15                   NaN               Tier 3      Grocery Store
# FDA15                  High               Tier 3  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type3
# FDA15                   NaN               Tier 2  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# FDA15                    5976.2208
# FDA15                    6474.2392
# FDA15                    5976.2208
# FDA15                     498.0184
# FDA15                    6474.2392
# FDA15                    6474.2392
# FDA15                    5976.2208

# %%
data.loc[['FDA15', 'FDA03']]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
# FDA03                   18.5          Regular         0.045464     Dairy
# FDA03                    NaN          Regular         0.045244     Dairy
# FDA03                   18.5          Regular         0.000000     Dairy
# FDA03                   18.5          Regular         0.076097     Dairy
# FDA03                   18.5          Regular         0.045426     Dairy
# FDA03                   18.5          Regular         0.045534     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# FDA15            248.5092            OUT035                       2004
# FDA15            249.6092            OUT018                       2009
# FDA15            248.9092            OUT010                       1998
# FDA15            250.6092            OUT013                       1987
# FDA15            249.5092            OUT027                       1985
# FDA15            248.8092            OUT017                       2007
# FDA03            144.1102            OUT046                       1997
# FDA03            146.8102            OUT027                       1985
# FDA03            144.2102            OUT035                       2004
# FDA03            145.8102            OUT010                       1998
# FDA03            144.9102            OUT013                       1987
# FDA03            146.3102            OUT049                       1999
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                   NaN               Tier 2  Supermarket Type1
# FDA15                 Small               Tier 2  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type2
# FDA15                   NaN               Tier 3      Grocery Store
# FDA15                  High               Tier 3  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type3
# FDA15                   NaN               Tier 2  Supermarket Type1
# FDA03                 Small               Tier 1  Supermarket Type1
# FDA03                Medium               Tier 3  Supermarket Type3
# FDA03                 Small               Tier 2  Supermarket Type1
# FDA03                   NaN               Tier 3      Grocery Store
# FDA03                  High               Tier 3  Supermarket Type1
# FDA03                Medium               Tier 1  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# FDA15                    5976.2208
# FDA15                    6474.2392
# FDA15                    5976.2208
# FDA15                     498.0184
# FDA15                    6474.2392
# FDA15                    6474.2392
# FDA15                    5976.2208
# FDA03                    2187.1530
# FDA03                    3499.4448
# FDA03                    2041.3428
# FDA03                     291.6204
# FDA03                    1895.5326
# FDA03                    3645.2550

# %%
data.loc[['FDA15', 'FDA03'], 'Item_Fat_Content']
# Out:
# Item_Identifier
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15         LF
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# Name: Item_Fat_Content, dtype: object

# %%
data.loc[['FDA15', 'FDA03'], ['Item_Fat_Content', 'Item_Type']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.loc[['FDA15', 'FDA03'], ['Item_Fat_Content', 'Item_Type']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._multi_take(self, tup)
#    1310 """
#    1311 Create the indexers for the passed tuple of keys, and
#    1312 executes the take operation. This allows the take operation to be
#    (...)
#    1323 values: same type as the object being indexed
#    1324 """
#    1325 # GH 836
#    1326 d = {
# -> 1327     axis: self._get_listlike_indexer(key, axis)
#    1328     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1329 }
#    1330 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['FDA15', 'FDA03'], dtype='object')] are in the [index]"

# %% [markdown]
# ---
#
#
# ### `TABLE OF CONTENTS`
#
# - How to select rows using the label of the index?
# - Difference between loc and iloc
#
#
# ---

# %%
sample_df=pd.DataFrame({
    'gender' :['M', 'F', 'M', 'M', 'F'],
    'grade'  :['A', 'A', 'B', 'B', 'A'],
    'marks'  :[95, 93, 90, 91, 98],
    'Id'    :['A101', 'A102', 'A103', 'A104', 'A105']
})
sample_df
# Out:
#   gender grade  marks    Id
# 0      M     A     95  A101
# 1      F     A     93  A102
# 2      M     B     90  A103
# 3      M     B     91  A104
# 4      F     A     98  A105

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    Id
# 2      M     B     90  A103
# 3      M     B     91  A104
# 4      F     A     98  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    Id
# 2      M     B     90  A103
# 3      M     B     91  A104

# %%
sample_df=sample_df.sort_values(by=['marks'])
sample_df
# Out:
#   gender grade  marks    Id
# 2      M     B     90  A103
# 3      M     B     91  A104
# 1      F     A     93  A102
# 0      M     A     95  A101
# 4      F     A     98  A105

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    Id
# 2      M     B     90  A103
# 3      M     B     91  A104
# 1      F     A     93  A102
# 0      M     A     95  A101
# 4      F     A     98  A105

# %%
sample_df.iloc[2:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sample_df.iloc[2:4]
#
# NameError: name 'sample_df' is not defined

# %%
sample_df.set_index('id' ,inplace=True)
sample_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sample_df.set_index('id' ,inplace=True)
#       2 sample_df
#
# NameError: name 'sample_df' is not defined

# %%
sample_df.iloc[2:4]

# %%
sample_df.loc['A104':'A102']

# %%
sample_df.loc[2:4]

# %% [markdown]
# ---
# ---
#
# <center><h1> 📍 📍 Subsetting: Value Based 📍 📍 </h1></center>
#
#
# ---
#
# ### `TABLE OF CONTENTS`
#
#  - How to select rows based on condition?
#  - How to select rows based on multiple conditions?
#  - How to select specific columns from a data?
#  - How to select rows based on a condition and view only the specific columms?
#  - How to select the columns with specific data types?
#
# ---
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.
#
# ---

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.loc[data.Outlet_Establishment_Year==1987]
# data[data.Outlet_Establishment_Year==1987]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# 6               Snack Foods   57.6588            OUT013
# 14    Fruits and Vegetables  196.4426            OUT013
# 20              Snack Foods  250.8724            OUT013
# 27              Hard Drinks   39.1164            OUT013
# ...                     ...       ...               ...
# 8462  Fruits and Vegetables   85.9856            OUT013
# 8466  Fruits and Vegetables   61.2536            OUT013
# 8484            Soft Drinks  129.9652            OUT013
# 8512                  Dairy  178.3028            OUT013
# 8518            Snack Foods  214.5218            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 14                         1987        High               Tier 3
# 20                         1987        High               Tier 3
# 27                         1987        High               Tier 3
# ...                         ...         ...                  ...
# 8462                       1987        High               Tier 3
# 8466                       1987        High               Tier 3
# 8484                       1987        High               Tier 3
# 8512                       1987        High               Tier 3
# 8518                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 14    Supermarket Type1          1977.4260
# 20    Supermarket Type1          3775.0860
# 27    Supermarket Type1           308.9312
# ...                 ...                ...
# 8462  Supermarket Type1          1494.0552
# 8466  Supermarket Type1           673.7896
# 8484  Supermarket Type1          2324.9736
# 8512  Supermarket Type1          2479.4392
# 8518  Supermarket Type1          2778.3834
#
# [932 rows x 12 columns]

# %%
data.loc[(data.Outlet_Establishment_Year == 2009) & (data.Outlet_Size == 'Medium')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 5              FDP36       10.395          Regular         0.000000
# 16             NCB42       11.800          Low Fat         0.008596
# 31             NCS17       18.600          Low Fat         0.080829
# 32             FDP33       18.700          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8506           DRF37       17.250          Low Fat         0.084676
# 8511           FDF05       17.500          Low Fat         0.026980
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8521           FDN46        7.210          Regular         0.145221
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 5           Baking Goods   51.4008            OUT018
# 16    Health and Hygiene  115.3492            OUT018
# 31    Health and Hygiene   96.4436            OUT018
# 32           Snack Foods  256.6672            OUT018
# ...                  ...       ...               ...
# 8506         Soft Drinks  263.1910            OUT018
# 8511        Frozen Foods  262.5910            OUT018
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8521         Snack Foods  103.1332            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                          2009      Medium               Tier 3
# 5                          2009      Medium               Tier 3
# 16                         2009      Medium               Tier 3
# 31                         2009      Medium               Tier 3
# 32                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8506                       2009      Medium               Tier 3
# 8511                       2009      Medium               Tier 3
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8521                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 1     Supermarket Type2           443.4228
# 5     Supermarket Type2           556.6088
# 16    Supermarket Type2          1621.8888
# 31    Supermarket Type2          2741.7644
# 32    Supermarket Type2          3068.0064
# ...                 ...                ...
# 8506  Supermarket Type2          3944.8650
# 8511  Supermarket Type2          4207.8560
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8521  Supermarket Type2          1845.5976
#
# [928 rows x 12 columns]

# %%
data[(data.Outlet_Establishment_Year == 1987) | (data.Outlet_Establishment_Year == 1988) | (data.Outlet_Establishment_Year == 1999)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 10             FDY07       11.800          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8475           NCS17       18.600          Low Fat         0.080627
# 8479           FDL10        8.395          Low Fat         0.039554
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 2                      Meat  141.6180            OUT049
# 4                 Household   53.8614            OUT013
# 6               Snack Foods   57.6588            OUT013
# 10    Fruits and Vegetables   45.5402            OUT049
# ...                     ...       ...               ...
# 8475     Health and Hygiene   92.5436            OUT049
# 8479            Snack Foods   99.1042            OUT049
# 8484            Soft Drinks  129.9652            OUT013
# 8512                  Dairy  178.3028            OUT013
# 8518            Snack Foods  214.5218            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 10                         1999      Medium               Tier 1
# ...                         ...         ...                  ...
# 8475                       1999      Medium               Tier 1
# 8479                       1999      Medium               Tier 1
# 8484                       1987        High               Tier 3
# 8512                       1987        High               Tier 3
# 8518                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 10    Supermarket Type1          1516.0266
# ...                 ...                ...
# 8475  Supermarket Type1           378.1744
# 8479  Supermarket Type1          2579.3092
# 8484  Supermarket Type1          2324.9736
# 8512  Supermarket Type1          2479.4392
# 8518  Supermarket Type1          2778.3834
#
# [1862 rows x 12 columns]

# %%
#  data[data.Outlet_Establishment_Year.isin([1987, 1988, 1999])]
data[data.Outlet_Establishment_Year.isin([1987, 1988])]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# 6               Snack Foods   57.6588            OUT013
# 14    Fruits and Vegetables  196.4426            OUT013
# 20              Snack Foods  250.8724            OUT013
# 27              Hard Drinks   39.1164            OUT013
# ...                     ...       ...               ...
# 8462  Fruits and Vegetables   85.9856            OUT013
# 8466  Fruits and Vegetables   61.2536            OUT013
# 8484            Soft Drinks  129.9652            OUT013
# 8512                  Dairy  178.3028            OUT013
# 8518            Snack Foods  214.5218            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 14                         1987        High               Tier 3
# 20                         1987        High               Tier 3
# 27                         1987        High               Tier 3
# ...                         ...         ...                  ...
# 8462                       1987        High               Tier 3
# 8466                       1987        High               Tier 3
# 8484                       1987        High               Tier 3
# 8512                       1987        High               Tier 3
# 8518                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 14    Supermarket Type1          1977.4260
# 20    Supermarket Type1          3775.0860
# 27    Supermarket Type1           308.9312
# ...                 ...                ...
# 8462  Supermarket Type1          1494.0552
# 8466  Supermarket Type1           673.7896
# 8484  Supermarket Type1          2324.9736
# 8512  Supermarket Type1          2479.4392
# 8518  Supermarket Type1          2778.3834
#
# [932 rows x 12 columns]

# %%
select_columns=['Item_Identifier', 'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size']
data[select_columns]
# Out:
#      Item_Identifier  Item_MRP  Outlet_Establishment_Year Outlet_Size
# 0              FDA15  249.8092                       1999      Medium
# 1              DRC01   48.2692                       2009      Medium
# 2              FDN15  141.6180                       1999      Medium
# 3              FDX07  182.0950                       1998         NaN
# 4              NCD19   53.8614                       1987        High
# ...              ...       ...                        ...         ...
# 8518           FDF22  214.5218                       1987        High
# 8519           FDS36  108.1570                       2002         NaN
# 8520           NCJ29   85.1224                       2004       Small
# 8521           FDN46  103.1332                       2009      Medium
# 8522           DRG01   75.4670                       1997       Small
#
# [8523 rows x 4 columns]

# %%
select_columns=['Item_Identifier', 'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size']
data[(data.Outlet_Establishment_Year == 1987) & (data.Outlet_Size == 'High')][select_columns]
# Out:
#      Item_Identifier  Item_MRP  Outlet_Establishment_Year Outlet_Size
# 4              NCD19   53.8614                       1987        High
# 6              FDO10   57.6588                       1987        High
# 14             FDF32  196.4426                       1987        High
# 20             FDN22  250.8724                       1987        High
# 27             DRJ59   39.1164                       1987        High
# ...              ...       ...                        ...         ...
# 8462           FDQ31   85.9856                       1987        High
# 8466           FDJ32   61.2536                       1987        High
# 8484           DRJ49  129.9652                       1987        High
# 8512           FDR26  178.3028                       1987        High
# 8518           FDF22  214.5218                       1987        High
#
# [932 rows x 4 columns]

# %%
data.loc[(data.Outlet_Establishment_Year == 1987) & (data.Outlet_Size == 'High'), select_columns]
# Out:
#      Item_Identifier  Item_MRP  Outlet_Establishment_Year Outlet_Size
# 4              NCD19   53.8614                       1987        High
# 6              FDO10   57.6588                       1987        High
# 14             FDF32  196.4426                       1987        High
# 20             FDN22  250.8724                       1987        High
# 27             DRJ59   39.1164                       1987        High
# ...              ...       ...                        ...         ...
# 8462           FDQ31   85.9856                       1987        High
# 8466           FDJ32   61.2536                       1987        High
# 8484           DRJ49  129.9652                       1987        High
# 8512           FDR26  178.3028                       1987        High
# 8518           FDF22  214.5218                       1987        High
#
# [932 rows x 4 columns]

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.select_dtypes('object')
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# 2               OUT049      Medium               Tier 1  Supermarket Type1
# 3               OUT010         NaN               Tier 3      Grocery Store
# 4               OUT013        High               Tier 3  Supermarket Type1
# ...                ...         ...                  ...                ...
# 8518            OUT013        High               Tier 3  Supermarket Type1
# 8519            OUT045         NaN               Tier 2  Supermarket Type1
# 8520            OUT035       Small               Tier 2  Supermarket Type1
# 8521            OUT018      Medium               Tier 3  Supermarket Type2
# 8522            OUT046       Small               Tier 1  Supermarket Type1
#
# [8523 rows x 7 columns]

# %%
data.select_dtypes('int64')
# Out:
#       Outlet_Establishment_Year
# 0                          1999
# 1                          2009
# 2                          1999
# 3                          1998
# 4                          1987
# ...                         ...
# 8518                       1987
# 8519                       2002
# 8520                       2004
# 8521                       2009
# 8522                       1997
#
# [8523 rows x 1 columns]

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Modifying Data 📍 📍</h1></center>
#
# ---
#
#
# ### `TABLE OF CONTENTS`
#
# - How to impute the missing values in any column?
# - How to update the values of a column with a new mapping?
# - How to create a new column by modifying the existing column?
# - How to convert categorical variables into numerical?
#
# ---
#
# ####  `READ THE DATA`
#
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.
#
# ---

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.loc[data.Item_Weight.isna()==True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
data.Item_Weight.mean()
# Out:
# 12.857645184135976

# %%
data.loc[(data.Item_Weight.isna()==True), 'Item_Weight'] = data.Item_Weight.mean()

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.Outlet_Size.mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
data.Outlet_Size.value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
data.loc[(data.Outlet_Size.isna()==True), 'Outlet_Size'] = 'medium'

# %%
data.Outlet_Size.fillna('medium', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14384\1345694925.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.Outlet_Size.fillna('medium', inplace=True)

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.Item_Fat_Content.value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
mapping = {
    'Low Fat' : 'LF',
    'Regular' : 'R',
    'LF' : 'LF',
    'reg': 'R',
    'low fat' : 'LF'
}

# %%
data.Item_Fat_Content.map(mapping)
# Out:
# 0       LF
# 1        R
# 2       LF
# 3        R
# 4       LF
#         ..
# 8518    LF
# 8519     R
# 8520    LF
# 8521     R
# 8522    LF
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
data.Item_Fat_Content = data.Item_Fat_Content.map(mapping)

# %%
data.Item_Fat_Content.value_counts()
# Out:
# Item_Fat_Content
# LF    5517
# R     3006
# Name: count, dtype: int64

# %%
data.Item_MRP
# Out:
# 0       249.8092
# 1        48.2692
# 2       141.6180
# 3       182.0950
# 4        53.8614
#           ...
# 8518    214.5218
# 8519    108.1570
# 8520     85.1224
# 8521    103.1332
# 8522     75.4670
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
data.Item_MRP.apply(lambda x : x/74)
# Out:
# 0       3.375800
# 1       0.652286
# 2       1.913757
# 3       2.460743
# 4       0.727857
#           ...
# 8518    2.898943
# 8519    1.461581
# 8520    1.150303
# 8521    1.393692
# 8522    1.019824
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92                R         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20                R         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
def convert (price):
    price = price/74
    price = price + 1.28
    return price

# %%
data['Item_MRP_in_USD_UPDATED'] = data.Item_MRP.apply(lambda x: convert(x))

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92                R         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20                R         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Item_MRP_in_USD_UPDATED
# 0  Supermarket Type1          3735.1380                 4.655800
# 1  Supermarket Type2           443.4228                 1.932286
# 2  Supermarket Type1          2097.2700                 3.193757
# 3      Grocery Store           732.3800                 3.740743
# 4  Supermarket Type1           994.7052                 2.007857

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92                R         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20                R         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Item_MRP_in_USD_UPDATED
# 0  Supermarket Type1          3735.1380                 4.655800
# 1  Supermarket Type2           443.4228                 1.932286
# 2  Supermarket Type1          2097.2700                 3.193757
# 3      Grocery Store           732.3800                 3.740743
# 4  Supermarket Type1           994.7052                 2.007857

# %%
data.shape
# Out:
# (8523, 13)

# %%
data = pd.get_dummies(data)

# %%
data.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales  Item_MRP_in_USD_UPDATED  Item_Identifier_DRA12  \
# 0          3735.1380                 4.655800                  False
# 1           443.4228                 1.932286                  False
# 2          2097.2700                 3.193757                  False
# 3           732.3800                 3.740743                  False
# 4           994.7052                 2.007857                  False
#
#    Item_Identifier_DRA24  Item_Identifier_DRA59  Item_Identifier_DRB01  ...  \
# 0                  False                  False                  False  ...
# 1                  False                  False                  False  ...
# 2                  False                  False                  False  ...
# 3                  False                  False                  False  ...
# 4                  False                  False                  False  ...
#
#    Outlet_Size_Medium  Outlet_Size_Small  Outlet_Size_medium  \
# 0                True              False               False
# 1                True              False               False
# 2                True              False               False
# 3               False              False                True
# 4               False              False               False
#
#    Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 0                         True                        False
# 1                        False                        False
# 2                         True                        False
# 3                        False                        False
# 4                        False                        False
#
#    Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 0                        False                      False
# 1                         True                      False
# 2                        False                      False
# 3                         True                       True
# 4                         True                      False
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                           True                          False
# 1                          False                           True
# 2                           True                          False
# 3                          False                          False
# 4                           True                          False
#
#    Outlet_Type_Supermarket Type3
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
# [5 rows x 1604 columns]

# %%
data.shape
# Out:
# (8523, 1604)

# %% [markdown]
# ---
# ---
#
# <center><h1> 📍 📍 Sorting the Data 📍 📍 </h1></center>
#
# ---
#
# In this notebook, we will see how to sort the data based on a single column and on multiple columns. Also we will see how to reset index after sorting the data.
#
# ---

# %%
import pandas as pd

# %%
data_frame=pd.DataFrame({
    'roll_no' : [105, 102, 104, 103, 101],
    'name'    :['Arun', 'Ujjwal', 'Preiya', 'Diwash', 'Aashik'],
    'grade'   :['B', 'A', 'B', 'C', 'A'],
    'marks'   :[98, 95, 90, 80, 88],
    'city'    :['Gur', 'Kathmandu', 'Kaliya', 'Rautahat', 'Jhapa']
})
data_frame
# Out:
#    roll_no    name grade  marks       city
# 0      105    Arun     B     98        Gur
# 1      102  Ujjwal     A     95  Kathmandu
# 2      104  Preiya     B     90     Kaliya
# 3      103  Diwash     C     80   Rautahat
# 4      101  Aashik     A     88      Jhapa

# %%
data_frame.sort_values(by=['roll_no'])
# Out:
#    roll_no    name grade  marks       city
# 4      101  Aashik     A     88      Jhapa
# 1      102  Ujjwal     A     95  Kathmandu
# 3      103  Diwash     C     80   Rautahat
# 2      104  Preiya     B     90     Kaliya
# 0      105    Arun     B     98        Gur

# %%
data_frame.sort_values(by=['grade'])
# Out:
#    roll_no    name grade  marks       city
# 1      102  Ujjwal     A     95  Kathmandu
# 4      101  Aashik     A     88      Jhapa
# 0      105    Arun     B     98        Gur
# 2      104  Preiya     B     90     Kaliya
# 3      103  Diwash     C     80   Rautahat

# %%
data_frame.sort_values(by=['grade', 'marks'], ascending=[True, False])
# Out:
#    roll_no    name grade  marks       city
# 1      102  Ujjwal     A     95  Kathmandu
# 4      101  Aashik     A     88      Jhapa
# 0      105    Arun     B     98        Gur
# 2      104  Preiya     B     90     Kaliya
# 3      103  Diwash     C     80   Rautahat

# %%
data_frame
# Out:
#    roll_no    name grade  marks       city
# 0      105    Arun     B     98        Gur
# 1      102  Ujjwal     A     95  Kathmandu
# 2      104  Preiya     B     90     Kaliya
# 3      103  Diwash     C     80   Rautahat
# 4      101  Aashik     A     88      Jhapa

# %%
data_frame.sort_values(by=['grade', 'marks'], ascending=[True, False], inplace=True)

# %%
data_frame
# Out:
#    roll_no    name grade  marks       city
# 1      102  Ujjwal     A     95  Kathmandu
# 4      101  Aashik     A     88      Jhapa
# 0      105    Arun     B     98        Gur
# 2      104  Preiya     B     90     Kaliya
# 3      103  Diwash     C     80   Rautahat

# %%
data_frame.reset_index()
# Out:
#    index  roll_no    name grade  marks       city
# 0      1      102  Ujjwal     A     95  Kathmandu
# 1      4      101  Aashik     A     88      Jhapa
# 2      0      105    Arun     B     98        Gur
# 3      2      104  Preiya     B     90     Kaliya
# 4      3      103  Diwash     C     80   Rautahat

# %%
data_frame.reset_index(inplace=True, drop=True)
data_frame
# Out:
#    roll_no    name grade  marks       city
# 0      102  Ujjwal     A     95  Kathmandu
# 1      101  Aashik     A     88      Jhapa
# 2      105    Arun     B     98        Gur
# 3      104  Preiya     B     90     Kaliya
# 4      103  Diwash     C     80   Rautahat

# %% [markdown]
# ---
# ---
#
# <center><h1> 📍 📍 Working with Multiple DataFrames 📍 📍 </h1></center>
#
#
# ---
#
# - In most of the real life projects you will not get data from a single resource. You might need to combine data that you gather from multiple sources. In this notebook, we will see how to work with multiple data files?
#
#
# ***We have already worked with big mart sales data. Here, we have divided the data based on different outlet size. Let's see how to work with the multiple files***
#
#
# ---
#
# #### `READ THE DATA`
#
# ---

# %%
import pandas as pd

# %%
# read the datasets
outlet_size_small = pd.read_csv("Data/outlet_size_small.csv")
outlet_size_medium = pd.read_csv("Data/outlet_size_medium.csv")
outlet_size_large = pd.read_csv("Data/outlet_size_high.csv")

# %%
outlet_size_small.shape, outlet_size_medium.shape, outlet_size_large.shape
# Out:
# ((2388, 9), (2793, 9), (932, 9))

# %%
Outlet_size_small.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 Outlet_size_small.head()
#
# NameError: name 'Outlet_size_small' is not defined

# %%
Outlet_size_medium.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 Outlet_size_medium.head()
#
# NameError: name 'Outlet_size_medium' is not defined

# %%
outlet_size_large.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCD19         8.93          Low Fat         0.000000
# 1           FDO10        13.65          Regular         0.012741
# 2           FDF32        16.35          Low Fat         0.068024
# 3           FDN22        18.85          Regular         0.138190
# 4           DRJ59        11.65          low fat         0.019356
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0              Household   53.8614            OUT013  Supermarket Type1
# 1            Snack Foods   57.6588            OUT013  Supermarket Type1
# 2  Fruits and Vegetables  196.4426            OUT013  Supermarket Type1
# 3            Snack Foods  250.8724            OUT013  Supermarket Type1
# 4            Hard Drinks   39.1164            OUT013  Supermarket Type1
#
#    Item_Outlet_Sales
# 0           994.7052
# 1           343.5528
# 2          1977.4260
# 3          3775.0860
# 4           308.9312

# %%
all_dataframes = [outlet_size_small, outlet_size_medium, outlet_size_large]

# %%
data=pd.concat(all_dataframes, axis=0)

# %%
data.shape
# Out:
# (6113, 9)

# %%
sample_dataframe = pd.DataFrame({
    'roll_no': [ 102, 101, 104, 103, 105],
    'name' : ['Aravind', 'Rahul', 'Prateek', 'Piyuesh', 'Kartik'],
    'grade': ['B', 'B', 'A', 'C', 'A'],
    'marks': [ 15, 15, 20, 4, 22],
    'city' : ['Gurugram', 'Delhi', 'Delhi', 'Gurugram', 'Hyderabad']
})
sample_dataframe
# Out:
#    roll_no     name grade  marks       city
# 0      102  Aravind     B     15   Gurugram
# 1      101    Rahul     B     15      Delhi
# 2      104  Prateek     A     20      Delhi
# 3      103  Piyuesh     C      4   Gurugram
# 4      105   Kartik     A     22  Hyderabad

# %%
phone_no = pd.DataFrame({'phone_no' : [9804222057, 9845261341, 9845406564, 9804222058, 9845393933]})
phone_no
# Out:
#      phone_no
# 0  9804222057
# 1  9845261341
# 2  9845406564
# 3  9804222058
# 4  9845393933

# %%
combine=pd.concat([sample_dataframe, phone_no], axis=1)
combine
# Out:
#    roll_no     name grade  marks       city    phone_no
# 0      102  Aravind     B     15   Gurugram  9804222057
# 1      101    Rahul     B     15      Delhi  9845261341
# 2      104  Prateek     A     20      Delhi  9845406564
# 3      103  Piyuesh     C      4   Gurugram  9804222058
# 4      105   Kartik     A     22  Hyderabad  9845393933

# %% [markdown]
# ---
#
# #### `Performing SQL-Like Joins in Pandas`
#
#
# #### `LET'S LEARN ABOUT THE JOINS IN PANDAS WITH SOME EXAMPLES`
#
# - We will create a sample dataframe of students data that will contain `roll_no`, `name`, `grade`, `marks` and `city`.
#
#
# ---

# %%
import pandas as pd

# %%
student_df =pd.DataFrame({
    'roll_no' :[105, 103, 104, 102, 101],
    'name'    :['Arun', 'Preiya', 'Ujjwal', 'Diwash', 'Pooja'],
    'grade'   :['B', 'A', 'B', 'A', 'B'],
    'Marks'   :[90, 98, 91, 93, 92],
    'city'   :['gur', 'rautahat', 'kathmandu', 'japa', 'bangmati']
})
student_df
# Out:
#    roll_no    name grade  Marks       city
# 0      105    Arun     B     90        gur
# 1      103  Preiya     A     98   rautahat
# 2      104  Ujjwal     B     91  kathmandu
# 3      102  Diwash     A     93       japa
# 4      101   Pooja     B     92   bangmati

# %%
city_state_mapping=pd.DataFrame({
    'city' :['kathmandu', 'gaur', 'japa', 'bagmati', 'rautahat'],
    'state' :['delhi', 'mumbi', 'bhair', 'up', 'assam']
})
city_state_mapping
# Out:
#         city  state
# 0  kathmandu  delhi
# 1       gaur  mumbi
# 2       japa  bhair
# 3    bagmati     up
# 4   rautahat  assam

# %%
city_state_mapping
# Out:
#         city  state
# 0  kathmandu  delhi
# 1       gaur  mumbi
# 2       japa  bhair
# 3    bagmati     up
# 4   rautahat  assam

# %%
student_df.merge(city_state_mapping, how='left', on='city')
# Out:
#    roll_no    name grade  Marks       city  state
# 0      105    Arun     B     90        gur    NaN
# 1      103  Preiya     A     98   rautahat  assam
# 2      104  Ujjwal     B     91  kathmandu  delhi
# 3      102  Diwash     A     93       japa  bhair
# 4      101   Pooja     B     92   bangmati    NaN

# %%
roll_no = pd.DataFrame({
    'roll_no' : [ 102, 103]
})
roll_no
# Out:
#    roll_no
# 0      102
# 1      103

# %%
student_df
# Out:
#    roll_no    name grade  Marks       city
# 0      105    Arun     B     90        gur
# 1      103  Preiya     A     98   rautahat
# 2      104  Ujjwal     B     91  kathmandu
# 3      102  Diwash     A     93       japa
# 4      101   Pooja     B     92   bangmati

# %%
student_df.merge(roll_no, how='right', on='roll_no')
# Out:
#    roll_no    name grade  Marks      city
# 0      102  Diwash     A     93      japa
# 1      103  Preiya     A     98  rautahat

# %%
student_selection = pd.DataFrame({
    'roll_no' : [102, 105, 101],
    'company' : ['ABC', 'XYZ', 'ABC'],
    'package (lpa)' : [ 8, 14.5, 11 ]
})
student_selection
# Out:
#    roll_no company  package (lpa)
# 0      102     ABC            8.0
# 1      105     XYZ           14.5
# 2      101     ABC           11.0

# %%
student_df
# Out:
#    roll_no    name grade  Marks       city
# 0      105    Arun     B     90        gur
# 1      103  Preiya     A     98   rautahat
# 2      104  Ujjwal     B     91  kathmandu
# 3      102  Diwash     A     93       japa
# 4      101   Pooja     B     92   bangmati

# %%
student_df.merge(student_selection, how='outer')
# Out:
#    roll_no    name grade  Marks       city company  package (lpa)
# 0      101   Pooja     B     92   bangmati     ABC           11.0
# 1      102  Diwash     A     93       japa     ABC            8.0
# 2      103  Preiya     A     98   rautahat     NaN            NaN
# 3      104  Ujjwal     B     91  kathmandu     NaN            NaN
# 4      105    Arun     B     90        gur     XYZ           14.5

# %%
student_df = pd.DataFrame({
    'college': ['ZU UNIVERSITY', 'ZU UNIVERSITY', 'ZU UNIVERSITY', 'ZU UNIVERSITY', 'ZU UNIVERSITY'],
    'roll_no': [ 102, 101, 104, 103, 105],
    'name' : ['Aravind', 'Rahul', 'Prateek', 'Piyuesh', 'Kartik'],
    'grade': ['B', 'B', 'A', 'C', 'A'],
    'marks': [ 15, 15, 20, 4, 22],
    'city' : ['Gurugram', 'Delhi', 'Delhi', 'Gurugram', 'Hyderabad']
})
student_df
# Out:
#          college  roll_no     name grade  marks       city
# 0  ZU UNIVERSITY      102  Aravind     B     15   Gurugram
# 1  ZU UNIVERSITY      101    Rahul     B     15      Delhi
# 2  ZU UNIVERSITY      104  Prateek     A     20      Delhi
# 3  ZU UNIVERSITY      103  Piyuesh     C      4   Gurugram
# 4  ZU UNIVERSITY      105   Kartik     A     22  Hyderabad

# %%
pool = pd.DataFrame({
        'college': ['ZU UNIVERSITY', 'ZU UNIVERSITY', 'AB UNIVERSITY', 'ZU UNIVERSITY','AB UNIVERSITY'],
        'name' : ['Aravind', 'Rahul', 'Rahul', 'Prateek', 'Harsh'],
        'company' : ['ABC', 'XYZ', 'ABC', 'AEP', 'ABC'],
        'package (lpa)' : [ 8, 14.5, 11, 6, 6 ]
})
pool
# Out:
#          college     name company  package (lpa)
# 0  ZU UNIVERSITY  Aravind     ABC            8.0
# 1  ZU UNIVERSITY    Rahul     XYZ           14.5
# 2  AB UNIVERSITY    Rahul     ABC           11.0
# 3  ZU UNIVERSITY  Prateek     AEP            6.0
# 4  AB UNIVERSITY    Harsh     ABC            6.0

# %%
student_df.merge(pool, how='inner', on=['college', 'name'])
# Out:
#          college  roll_no     name grade  marks      city company  \
# 0  ZU UNIVERSITY      102  Aravind     B     15  Gurugram     ABC
# 1  ZU UNIVERSITY      101    Rahul     B     15     Delhi     XYZ
# 2  ZU UNIVERSITY      104  Prateek     A     20     Delhi     AEP
#
#    package (lpa)
# 0            8.0
# 1           14.5
# 2            6.0

# %%
previous_data = pd.read_csv('Data/outlet_size_concatenated_data.csv')

# %%
previous_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03        18.50          Regular         0.045464        Dairy
# 1           FDS46        17.60          Regular         0.047257  Snack Foods
# 2           FDP49         9.00          Regular         0.069089    Breakfast
# 3           FDU02        13.35          Low Fat         0.102492        Dairy
# 4           NCB30        14.60          Low Fat         0.025698    Household
#
#    Item_MRP Outlet_Identifier        Outlet_Type  Item_Outlet_Sales
# 0  144.1102            OUT046  Supermarket Type1          2187.1530
# 1  119.6782            OUT046  Supermarket Type1          2145.2076
# 2   56.3614            OUT046  Supermarket Type1          1547.3192
# 3  230.5352            OUT035  Supermarket Type1          2748.4224
# 4  196.5084            OUT035  Supermarket Type1          1587.2672

# %%
outlet_data = pd.read_csv('Data/outlet_data.csv')

# %%
outlet_data.head()
# Out:
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT013                       1987        High
# 1            OUT018                       2009      Medium
# 2            OUT019                       1985       Small
# 3            OUT027                       1985      Medium
# 4            OUT035                       2004       Small
#
#   Outlet_Location_Type
# 0               Tier 3
# 1               Tier 3
# 2               Tier 1
# 3               Tier 3
# 4               Tier 2

# %%
combined_data = previous_data.merge(outlet_data, how='left', on='Outlet_Identifier')

# %%
combined_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03        18.50          Regular         0.045464        Dairy
# 1           FDS46        17.60          Regular         0.047257  Snack Foods
# 2           FDP49         9.00          Regular         0.069089    Breakfast
# 3           FDU02        13.35          Low Fat         0.102492        Dairy
# 4           NCB30        14.60          Low Fat         0.025698    Household
#
#    Item_MRP Outlet_Identifier        Outlet_Type  Item_Outlet_Sales  \
# 0  144.1102            OUT046  Supermarket Type1          2187.1530
# 1  119.6782            OUT046  Supermarket Type1          2145.2076
# 2   56.3614            OUT046  Supermarket Type1          1547.3192
# 3  230.5352            OUT035  Supermarket Type1          2748.4224
# 4  196.5084            OUT035  Supermarket Type1          1587.2672
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 0                       1997       Small               Tier 1
# 1                       1997       Small               Tier 1
# 2                       1997       Small               Tier 1
# 3                       2004       Small               Tier 2
# 4                       2004       Small               Tier 2

# %%
combined_data.shape
# Out:
# (6113, 12)

# %%
item_data = pd.read_csv('Data/item_idenifier.csv')

# %%
item_data.head()
# Out:
#   Item_Identifier
# 0           DRI51
# 1           FDL48
# 2           FDL38
# 3           FDF17
# 4           FDN56

# %%
item_data.shape
# Out:
# (100, 1)

# %%
item_details = combined_data.merge(item_data, how='right',on='Item_Identifier')

# %%
item_details
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             DRI51        17.25          Low Fat         0.042234
# 1             DRI51        17.25          Low Fat         0.042414
# 2             DRI51          NaN          Low Fat         0.042037
# 3             FDL48        19.35          Regular         0.082251
# 4             FDL48        19.35          Regular         0.082266
# ..              ...          ...              ...              ...
# 417           FDD57        18.10               LF         0.022381
# 418           FDG41         8.84          Regular         0.076548
# 419           FDG41         8.84          Regular         0.076681
# 420           FDG41         8.84          Regular         0.076874
# 421           NCM42         6.13          Low Fat         0.028366
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                    Dairy  173.3764            OUT035  Supermarket Type1
# 1                    Dairy  173.1764            OUT018  Supermarket Type2
# 2                    Dairy  172.6764            OUT027  Supermarket Type3
# 3             Baking Goods   48.7034            OUT035  Supermarket Type1
# 4             Baking Goods   48.8034            OUT046  Supermarket Type1
# ..                     ...       ...               ...                ...
# 417  Fruits and Vegetables   93.6094            OUT013  Supermarket Type1
# 418           Frozen Foods  109.5228            OUT035  Supermarket Type1
# 419           Frozen Foods  110.7228            OUT049  Supermarket Type1
# 420           Frozen Foods  109.9228            OUT018  Supermarket Type2
# 421              Household  110.0912            OUT049  Supermarket Type1
#
#      Item_Outlet_Sales  Outlet_Establishment_Year Outlet_Size  \
# 0            2061.3168                       2004       Small
# 1            4466.1864                       2009      Medium
# 2            6183.9504                       1985      Medium
# 3             534.6374                       2004       Small
# 4             340.2238                       1997       Small
# ..                 ...                        ...         ...
# 417           476.0470                       1987        High
# 418          1657.8420                       2004       Small
# 419          1657.8420                       1999      Medium
# 420          1547.3192                       2009      Medium
# 421          1637.8680                       1999      Medium
#
#     Outlet_Location_Type
# 0                 Tier 2
# 1                 Tier 3
# 2                 Tier 3
# 3                 Tier 2
# 4                 Tier 1
# ..                   ...
# 417               Tier 3
# 418               Tier 2
# 419               Tier 1
# 420               Tier 3
# 421               Tier 1
#
# [422 rows x 12 columns]

# %% [markdown]
# ---
#
# <center><h1> 📍 📍 Aggregating and Summarizing DataFrames 📍 📍 </h1></center>
#
# ---
#
# - How to calculate sum, mean, median and mode of a column?
# - How to get the summary of the numerical variables?
# - How to get number of missing values in each columns?
# - How to group the data based on categories of one column?
# - How to group the data based on categories of multiple columns?
# - How to create new feature using the aggregated results of a column?
#
# ---
#
# #### `READ THE DATASET`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.

# %%
import pandas as pd

# %%
data=pd.read_csv("Data/big_mart_Sales.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.Item_MRP.sum()
# Out:
# 1201681.4808

# %%
data.Item_MRP.mean()
# Out:
# 140.9927819781767

# %%
data.Item_MRP.median()
# Out:
# 143.0128

# %%
data.Item_MRP.mode()
# Out:
# 0    172.0422
# Name: Item_MRP, dtype: float64

# %%
data.Outlet_Type.mode()
# Out:
# 0    Supermarket Type1
# Name: Outlet_Type, dtype: object

# %%
data.Outlet_Type.value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ### Group BY

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
d = data.groupby(['Item_MRP'])
d

# %%
d.first()
# Out:
#          Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_MRP
# 31.2900            DRK12          NaN          Low Fat         0.041683
# 31.4900            DRK12        9.500          Low Fat         0.041851
# 31.8900            DRK12        9.500          Low Fat         0.042057
# 31.9558            FDX59       10.195          Low Fat         0.051618
# 32.0558            FDV28       16.100          Regular         0.159698
# ...                  ...          ...              ...              ...
# 266.1884           FDK51       19.850          Low Fat         0.005243
# 266.2884           NCS29        9.000          Low Fat         0.069654
# 266.5884           FDS13        9.000          Low Fat         0.217994
# 266.6884           FDK51       19.850          Low Fat         0.008763
# 266.8884           FDS13        6.465          Low Fat         0.125210
#
#                    Item_Type Outlet_Identifier  Outlet_Establishment_Year  \
# Item_MRP
# 31.2900          Soft Drinks            OUT027                       1985
# 31.4900          Soft Drinks            OUT013                       1987
# 31.8900          Soft Drinks            OUT018                       2009
# 31.9558               Breads            OUT013                       1987
# 32.0558         Frozen Foods            OUT035                       2004
# ...                      ...               ...                        ...
# 266.1884               Dairy            OUT049                       1999
# 266.2884  Health and Hygiene            OUT049                       1999
# 266.5884              Canned            OUT019                       1985
# 266.6884               Dairy            OUT010                       1998
# 266.8884              Canned            OUT017                       2007
#
#          Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_MRP
# 31.2900       Medium               Tier 3  Supermarket Type3
# 31.4900         High               Tier 3  Supermarket Type1
# 31.8900       Medium               Tier 3  Supermarket Type2
# 31.9558         High               Tier 3  Supermarket Type1
# 32.0558        Small               Tier 2  Supermarket Type1
# ...              ...                  ...                ...
# 266.1884      Medium               Tier 1  Supermarket Type1
# 266.2884      Medium               Tier 1  Supermarket Type1
# 266.5884       Small               Tier 1      Grocery Store
# 266.6884        High               Tier 3      Grocery Store
# 266.8884       Small               Tier 2  Supermarket Type1
#
#           Item_Outlet_Sales
# Item_MRP
# 31.2900            898.8300
# 31.4900            466.0600
# 31.8900            366.1900
# 31.9558            373.5138
# 32.0558           1018.6740
# ...                     ...
# 266.1884          3179.8608
# 266.2884          2914.8724
# 266.5884          1324.9420
# 266.6884           264.9884
# 266.8884          1059.9536
#
# [5938 rows x 11 columns]

# %% [markdown]
# ### Group By Mean

# %%
d.mean(numeric_only=True)
# Out:
#           Item_Weight  Item_Visibility  Outlet_Establishment_Year  \
# Item_MRP
# 31.2900           NaN         0.041683                     1985.0
# 31.4900        9.5000         0.041851                     1987.0
# 31.8900        9.5000         0.042057                     2009.0
# 31.9558       10.1950         0.045625                     1986.0
# 32.0558       16.1000         0.159698                     2004.0
# ...               ...              ...                        ...
# 266.1884      13.1575         0.064823                     1993.0
# 266.2884       9.0000         0.069654                     1999.0
# 266.5884       9.0000         0.143763                     1994.5
# 266.6884      14.4250         0.039125                     1992.5
# 266.8884      11.7325         0.132366                     2002.0
#
#           Item_Outlet_Sales
# Item_MRP
# 31.2900            898.8300
# 31.4900            466.0600
# 31.8900            366.1900
# 31.9558            679.1160
# 32.0558           1018.6740
# ...                     ...
# 266.1884          4239.8144
# 266.2884          2914.8724
# 266.5884          3974.8260
# 266.6884          2119.9072
# 266.8884          3047.3666
#
# [5938 rows x 4 columns]

# %%
d.first().mean(numeric_only = True)
# Out:
# Item_Weight                    12.854122
# Item_Visibility                 0.066643
# Outlet_Establishment_Year    1997.846581
# Item_Outlet_Sales            2194.070122
# dtype: float64

# %%
# d.max()

# %%
d = data.groupby(['Outlet_Size', 'Item_Type'])
# d.first(['Item_Type']).mode()

# data['Item_Type'].value_counts()

# d.first().mode()

# %%
d['Item_MRP']

# %%
pd.pivot_table(data, index='Item_Type', values="Item_MRP", aggfunc= 'mean')
# Out:
#                          Item_MRP
# Item_Type
# Baking Goods           126.380766
# Breads                 140.952669
# Breakfast              141.788151
# Canned                 139.763832
# Dairy                  148.499208
# Frozen Foods           138.503366
# Fruits and Vegetables  144.581235
# Hard Drinks            137.077928
# Health and Hygiene     130.818921
# Household              149.424753
# Meat                   139.882032
# Others                 132.851430
# Seafood                141.841719
# Snack Foods            146.194934
# Soft Drinks            131.492506
# Starchy Foods          147.838023

# %%
pd.pivot_table(data, index= ['Outlet_Size', 'Item_Type'], values= 'Item_MRP', aggfunc= 'mean')
# Out:
#                                      Item_MRP
# Outlet_Size Item_Type
# High        Baking Goods           129.202044
#             Breads                 133.758960
#             Breakfast              147.490585
#             Canned                 135.442708
#             Dairy                  153.509173
#             Frozen Foods           136.829250
#             Fruits and Vegetables  145.572870
#             Hard Drinks            141.927522
#             Health and Hygiene     135.110980
#             Household              147.097522
#             Meat                   137.244790
#             Others                 132.576613
#             Seafood                134.864240
#             Snack Foods            145.847086
#             Soft Drinks            131.758473
#             Starchy Foods          158.157074
# Medium      Baking Goods           126.178568
#             Breads                 140.861039
#             Breakfast              134.537511
#             Canned                 138.124851
#             Dairy                  148.512174
#             Frozen Foods           140.557015
#             Fruits and Vegetables  142.971470
#             Hard Drinks            142.837696
#             Health and Hygiene     128.701865
#             Household              147.711330
#             Meat                   136.419132
#             Others                 127.836181
#             Seafood                140.857619
#             Snack Foods            148.779195
#             Soft Drinks            128.269682
#             Starchy Foods          148.419504
# Small       Baking Goods           125.213364
#             Breads                 145.523651
#             Breakfast              130.568027
#             Canned                 142.295429
#             Dairy                  145.942101
#             Frozen Foods           137.838544
#             Fruits and Vegetables  148.313370
#             Hard Drinks            129.758784
#             Health and Hygiene     131.831535
#             Household              153.965439
#             Meat                   145.699250
#             Others                 137.889211
#             Seafood                144.281760
#             Snack Foods            144.351896
#             Soft Drinks            132.855043
#             Starchy Foods          150.270174

# %%
pd.crosstab(data['Outlet_Size'], data['Item_Type'])
# Out:
# Item_Type    Baking Goods  Breads  Breakfast  Canned  Dairy  Frozen Foods  \
# Outlet_Size
# High                   73      25         13      65     80            92
# Medium                203      83         36     217    218           274
# Small                 187      71         30     189    198           249
#
# Item_Type    Fruits and Vegetables  Hard Drinks  Health and Hygiene  \
# Outlet_Size
# High                           142           23                  61
# Medium                         413           75                 170
# Small                          328           50                 136
#
# Item_Type    Household  Meat  Others  Seafood  Snack Foods  Soft Drinks  \
# Outlet_Size
# High               103    41      16        5          125           49
# Medium             289   149      52       21          408          137
# Small              257   119      55       20          335          126
#
# Item_Type    Starchy Foods
# Outlet_Size
# High                    19
# Medium                  48
# Small                   38

# %%
average_item_visibility = data.groupby(['Item_Identifier'])['Item_Visibility'].mean().reset_index()
average_item_visibility
# Out:
#      Item_Identifier  Item_Visibility
# 0              DRA12         0.031956
# 1              DRA24         0.048062
# 2              DRA59         0.134718
# 3              DRB01         0.082126
# 4              DRB13         0.008002
# ...              ...              ...
# 1554           NCZ30         0.024956
# 1555           NCZ41         0.051623
# 1556           NCZ42         0.009044
# 1557           NCZ53         0.027775
# 1558           NCZ54         0.080426
#
# [1559 rows x 2 columns]

# %%
def get_item_visibility(x) :
    return average_item_visibility.loc[(average_item_visibility.Item_Identifier == x), 'Item_Visibility'].values[0]

# %%
get_item_visibility('DRA24')
# Out:
# 0.04806226414285714

# %%
data['average_item_visibility'] = data.Item_Identifier.apply(get_item_visibility)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  average_item_visibility
# 0  Supermarket Type1          3735.1380                 0.017387
# 1  Supermarket Type2           443.4228                 0.019219
# 2  Supermarket Type1          2097.2700                 0.020145
# 3      Grocery Store           732.3800                 0.015274
# 4  Supermarket Type1           994.7052                 0.008082

# %%
data['average_item_visibility_2'] = data.groupby(['Item_Identifier'])['Item_Visibility'].transform('mean')

# %%
data[['average_item_visibility', 'average_item_visibility_2']]
# Out:
#       average_item_visibility  average_item_visibility_2
# 0                    0.017387                   0.017387
# 1                    0.019219                   0.019219
# 2                    0.020145                   0.020145
# 3                    0.015274                   0.015274
# 4                    0.008082                   0.008082
# ...                       ...                        ...
# 8518                 0.061705                   0.061705
# 8519                 0.046952                   0.046952
# 8520                 0.035203                   0.035203
# 8521                 0.120686                   0.120686
# 8522                 0.051565                   0.051565
#
# [8523 rows x 2 columns]

# %% [markdown]
# ---
#
# <center><h1>📍 📍 Preprocessing Timeseries Data 📍 📍</h1></center>
#
# ---
#
#
# **`Pandas`** contains extensive capabilities and features for working with time series data for all domains. Using the NumPy datetime64 and timedelta64 dtypes, pandas has consolidated a large number of features from other Python libraries like scikits.timeseries as well as created a tremendous amount of new functionality for manipulating time series data.
#
# ---

# %%
import pandas as pd
import datetime

# %%
data=pd.read_csv("Data/time_series.csv")

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %%
data.Datetime=pd.to_datetime(data.Datetime)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14384\1459847311.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data.Datetime=pd.to_datetime(data.Datetime)

# %%
data.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %%
data
# Out:
#           ID            Datetime  Count
# 0          0 2012-08-25 00:00:00      8
# 1          1 2012-08-25 01:00:00      2
# 2          2 2012-08-25 02:00:00      6
# 3          3 2012-08-25 03:00:00      2
# 4          4 2012-08-25 04:00:00      2
# ...      ...                 ...    ...
# 18283  18283 2014-09-25 19:00:00    868
# 18284  18284 2014-09-25 20:00:00    732
# 18285  18285 2014-09-25 21:00:00    702
# 18286  18286 2014-09-25 22:00:00    580
# 18287  18287 2014-09-25 23:00:00    534
#
# [18288 rows x 3 columns]

# %%
data.Datetime.apply(lambda x: x.day_name())
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 18283    Thursday
# 18284    Thursday
# 18285    Thursday
# 18286    Thursday
# 18287    Thursday
# Name: Datetime, Length: 18288, dtype: object

# %%
data.Datetime.apply(lambda x: x.month_name())
# Out:
# 0           August
# 1           August
# 2           August
# 3           August
# 4           August
#            ...
# 18283    September
# 18284    September
# 18285    September
# 18286    September
# 18287    September
# Name: Datetime, Length: 18288, dtype: object

# %%
data_2 = pd.read_csv('Data/time_series_2.csv')

# %%
data_2
# Out:
#           ID      Datetime  Count
# 0          0  25 Aug 2012       8
# 1          1  25 Aug 2012       2
# 2          2  25 Aug 2012       6
# 3          3  25 Aug 2012       2
# 4          4  25 Aug 2012       2
# ...      ...           ...    ...
# 18283  18283  25 Sep 2014     868
# 18284  18284  25 Sep 2014     732
# 18285  18285  25 Sep 2014     702
# 18286  18286  25 Sep 2014     580
# 18287  18287  25 Sep 2014     534
#
# [18288 rows x 3 columns]

# %%
data
# Out:
#           ID            Datetime  Count
# 0          0 2012-08-25 00:00:00      8
# 1          1 2012-08-25 01:00:00      2
# 2          2 2012-08-25 02:00:00      6
# 3          3 2012-08-25 03:00:00      2
# 4          4 2012-08-25 04:00:00      2
# ...      ...                 ...    ...
# 18283  18283 2014-09-25 19:00:00    868
# 18284  18284 2014-09-25 20:00:00    732
# 18285  18285 2014-09-25 21:00:00    702
# 18286  18286 2014-09-25 22:00:00    580
# 18287  18287 2014-09-25 23:00:00    534
#
# [18288 rows x 3 columns]

# %%
data['name']=data.Datetime.dt.month
data['month_name']=data.Datetime.dt.month_name()

# %%
data
# Out:
#           ID            Datetime  Count  name month_name
# 0          0 2012-08-25 00:00:00      8     8     August
# 1          1 2012-08-25 01:00:00      2     8     August
# 2          2 2012-08-25 02:00:00      6     8     August
# 3          3 2012-08-25 03:00:00      2     8     August
# 4          4 2012-08-25 04:00:00      2     8     August
# ...      ...                 ...    ...   ...        ...
# 18283  18283 2014-09-25 19:00:00    868     9  September
# 18284  18284 2014-09-25 20:00:00    732     9  September
# 18285  18285 2014-09-25 21:00:00    702     9  September
# 18286  18286 2014-09-25 22:00:00    580     9  September
# 18287  18287 2014-09-25 23:00:00    534     9  September
#
# [18288 rows x 5 columns]

# %%
data['day_name'] = data.Datetime.dt.day_name()
data['day_of_week'] = data.Datetime.dt.dayofweek
data['day_of_year'] = data.Datetime.dt.dayofyear

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year
# 0          238
# 1          238
# 2          238
# 3          238
# 4          238

# %% [markdown]
# ---
#
# #### `DIFFERENCE BETWEEN 2 DATES`
#
# ---
#
#
# ***Add the current date in the new column***
#
# ---

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year
# 0          238
# 1          238
# 2          238
# 3          238
# 4          238

# %%
data['today']=pd.to_datetime(datetime.date.today())

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year      today
# 0          238 2025-03-04
# 1          238 2025-03-04
# 2          238 2025-03-04
# 3          238 2025-03-04
# 4          238 2025-03-04

# %%
difference_of_dates = data['today']-data['Datetime']

# %%
difference_of_dates
# Out:
# 0       4574 days 00:00:00
# 1       4573 days 23:00:00
# 2       4573 days 22:00:00
# 3       4573 days 21:00:00
# 4       4573 days 20:00:00
#                ...
# 18283   3812 days 05:00:00
# 18284   3812 days 04:00:00
# 18285   3812 days 03:00:00
# 18286   3812 days 02:00:00
# 18287   3812 days 01:00:00
# Length: 18288, dtype: timedelta64[ns]

# %%
difference_of_dates.apply(lambda x : x.days)
# Out:
# 0        4574
# 1        4573
# 2        4573
# 3        4573
# 4        4573
#          ...
# 18283    3812
# 18284    3812
# 18285    3812
# 18286    3812
# 18287    3812
# Length: 18288, dtype: int64

# %%
data['difference_of_dates']=difference_of_dates.apply(lambda x : x.days)

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year      today  difference_of_dates
# 0          238 2025-03-04                 4574
# 1          238 2025-03-04                 4573
# 2          238 2025-03-04                 4573
# 3          238 2025-03-04                 4573
# 4          238 2025-03-04                 4573

# %%
# set the current time as of Asia
data['asia_timezone'] = data.Datetime.dt.tz_localize('Asia/Calcutta')

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year      today  difference_of_dates             asia_timezone
# 0          238 2025-03-04                 4574 2012-08-25 00:00:00+05:30
# 1          238 2025-03-04                 4573 2012-08-25 01:00:00+05:30
# 2          238 2025-03-04                 4573 2012-08-25 02:00:00+05:30
# 3          238 2025-03-04                 4573 2012-08-25 03:00:00+05:30
# 4          238 2025-03-04                 4573 2012-08-25 04:00:00+05:30

# %%
data['utc_timezone'] = data.asia_timezone.dt.tz_convert('UTC')

# %%
data.head()
# Out:
#    ID            Datetime  Count  name month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8     8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2     8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6     8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2     8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2     8     August  Saturday            5
#
#    day_of_year      today  difference_of_dates             asia_timezone  \
# 0          238 2025-03-04                 4574 2012-08-25 00:00:00+05:30
# 1          238 2025-03-04                 4573 2012-08-25 01:00:00+05:30
# 2          238 2025-03-04                 4573 2012-08-25 02:00:00+05:30
# 3          238 2025-03-04                 4573 2012-08-25 03:00:00+05:30
# 4          238 2025-03-04                 4573 2012-08-25 04:00:00+05:30
#
#                utc_timezone
# 0 2012-08-24 18:30:00+00:00
# 1 2012-08-24 19:30:00+00:00
# 2 2012-08-24 20:30:00+00:00
# 3 2012-08-24 21:30:00+00:00
# 4 2012-08-24 22:30:00+00:00

# %%
data[['asia_timezone', 'utc_timezone']]
# Out:
#                   asia_timezone              utc_timezone
# 0     2012-08-25 00:00:00+05:30 2012-08-24 18:30:00+00:00
# 1     2012-08-25 01:00:00+05:30 2012-08-24 19:30:00+00:00
# 2     2012-08-25 02:00:00+05:30 2012-08-24 20:30:00+00:00
# 3     2012-08-25 03:00:00+05:30 2012-08-24 21:30:00+00:00
# 4     2012-08-25 04:00:00+05:30 2012-08-24 22:30:00+00:00
# ...                         ...                       ...
# 18283 2014-09-25 19:00:00+05:30 2014-09-25 13:30:00+00:00
# 18284 2014-09-25 20:00:00+05:30 2014-09-25 14:30:00+00:00
# 18285 2014-09-25 21:00:00+05:30 2014-09-25 15:30:00+00:00
# 18286 2014-09-25 22:00:00+05:30 2014-09-25 16:30:00+00:00
# 18287 2014-09-25 23:00:00+05:30 2014-09-25 17:30:00+00:00
#
# [18288 rows x 2 columns]

# %%
data['asia_timezone'][18287]
# Out:
# Timestamp('2014-09-25 23:00:00+0530', tz='Asia/Calcutta')

# %%
data['utc_timezone'][18287]
# Out:
# Timestamp('2014-09-25 17:30:00+0000', tz='UTC')

# %%
data_with_unix_ts = pd.read_csv('Data/data_with_timestamp.csv')

# %%
data_with_unix_ts.head()
# Out:
#    ID   timestamp  Count
# 0   0  1345852800      8
# 1   1  1345856400      2
# 2   2  1345860000      6
# 3   3  1345863600      2
# 4   4  1345867200      2

# %%
data_with_unix_ts.timestamp = pd.to_datetime(data_with_unix_ts.timestamp, unit='s')

# %%
data_with_unix_ts.head()
# Out:
#    ID           timestamp  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %% [markdown]
# ---
# ---
#
# <center><h1> 📍 📍 Visualization with Matplotlib 📍 📍</h1></center>
#
# ---
#
# ### `Introduction`
#
# - Making plots and static or interactive visualizations is one of the most important tasks in data analysis. It may be a part of the exploratory process; for example, helping identify outliers, needed data transformations, or coming up with ideas for models.
#
# - Matplotlib is the most extensively used library of python for data visualization due to it's high flexibility and extensive functionality that it provides.
#
#
# ---
# ### `Table of Contents`
#
# 1. Setting up
#     - Importing matplotlib
#     - Matplotlib for Jupyter notebook
#     - Dataset
#     - Documentation
# 2. Matplotlib basics
#     - Make a simple plot
#     - Labels, and Legends
#     - Size, Colors, Markers, and Line Styles
#     - Figures and subplots
# 3. Line Chart
# 4. Bar Chart
# 5. Histogram
# 6. Box plot
# 7. Violin plot
# 8. Scatter plot
# 9. Bubble plot
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
height=[140, 150, 160, 170, 180]
weight=[60, 70, 80, 90, 100]
plt.plot(height, weight);

# %%
plt.plot(height, weight)
plt.title("Relationship Between Height and Weight")
plt.xlabel("Height")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
calories_burnt=[65, 75, 95, 99, 105]
plt.plot(calories_burnt)
plt.plot(weight);

# %%
plt.plot(calories_burnt)
plt.plot(weight)
plt.legend(['calories burnt', 'weight'], loc='lower right');

# %%
plt.plot(calories_burnt)
plt.plot(weight)
plt.legend(labels=['calories burnt', 'weight'], loc='lower right')
plt.xticks(ticks=[0, 1, 2, 3], labels=['p1', 'p2', 'p3', 'p4']);

# %%
plt.figure(figsize=(15,5))
plt.plot(calories_burnt, marker= 'o')
plt.plot(weight, marker = '*')
plt.legend(labels=['Calories Burnt', 'Weight'], loc='lower right')
plt.xticks(ticks=[0,1,2,3], labels=['p1', 'p2', 'p3', 'p4']);

# %%
plt.plot(calories_burnt, marker= 'o')
plt.plot(weight, marker = '*')
plt.plot(weight, '--r', marker='*')
plt.legend(labels=['Calories Burnt', 'Weight'], loc='lower right')
plt.xticks(ticks=[0,1,2,3], labels=['p1', 'p2', 'p3', 'p4']);

# %%
fig, ax=plt.subplots(nrows =2, ncols=2, figsize=(6,6))
ax[0, 1].plot(calories_burnt, 'go')
ax[0, 1].plot(weight)
ax[0, 0].set_title("Calories Burnt")
ax[0, 1].set_title("Weight")
ax[0, 0].set_xticks(ticks=[0, 1, 2, 3]);
ax[0, 1].set_xticks(ticks=[0, 1, 2, 3]);
ax[0, 0].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);
ax[0, 1].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharex=True, sharey=True)
ax[0].plot(calories_burnt,'go')
ax[1].plot(weight)
ax[0].set_title("Calories Burnt")
ax[1].set_title("Weight")
ax[0].set_xticks(ticks=[0,1,2,3]);
ax[1].set_xticks(ticks=[0,1,2,3]);
ax[0].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);
ax[1].set_xticklabels(labels=['p1', 'p2', 'p3', 'p4']);

# %%
# read the dataset
data_BM = pd.read_csv('Data/bigmart_data.csv')
# drop the null values
data_BM = data_BM.dropna(how="any")
# view the top results
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 4        High               Tier 3  Supermarket Type1           994.7052
# 5      Medium               Tier 3  Supermarket Type2           556.6088

# %%
price_by_item = data_BM.groupby('Outlet_Establishment_Year').Item_Outlet_Sales.mean()
price_by_item
# Out:
# Outlet_Establishment_Year
# 1987    2298.995256
# 1997    2277.844267
# 1999    2348.354635
# 2004    2438.841866
# 2009    1995.498739
# Name: Item_Outlet_Sales, dtype: float64

# %%
price_by_item=data_BM.groupby('Item_Type').Item_MRP.mean()[:10]
x=price_by_item.index.tolist()
y=price_by_item.values.tolist()
plt.figure(figsize=(14, 4))
plt.title('Mean price of each item')
plt.xlabel('Item Type')
plt.ylabel('Mean price')
plt.xticks(labels=x, ticks=np.arange(len(x)))
plt.plot(x, y, marker='o')

# %%
sales_by_outlet_size=data_BM.groupby('Outlet_Size').Item_Outlet_Sales.mean()
sales_by_outlet_size.sort_values(inplace=True)
x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()
plt.xlabel('Outlet Size')
plt.ylabel('Sales')
plt.title('Mean sales for each outlet type')
plt.xticks(labels=x, ticks=np.arange(len(x)))
plt.bar(x, y, color=['red', 'orange', 'yellow' ])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.title('Item MRP (price) distribution')
plt.xlabel('Item_MRP')
plt.ylabel('Frequency')
plt.hist(data_BM['Item_MRP'], bins=20, color='lightblue');

# %%
data = data_BM[['Item_Outlet_Sales']]
red_diamond = dict(markerfacecolor='r', marker='D')
plt.title('Item Sales distribution')
plt.boxplot(data.values, labels=['Item Sales'], flierprops=red_diamond);
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15272\4180498478.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values, labels=['Item Sales'], flierprops=red_diamond);

# %%
data = data_BM[['Item_Weight', 'Item_MRP']]
red_diamond = dict(markerfacecolor='r', marker='D')
fig, ax = plt.subplots()
plt.boxplot(data.values, labels=['Item Weight', 'Item MRP (price)'], flierprops=red_diamond);
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15272\806255893.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values, labels=['Item Weight', 'Item MRP (price)'], flierprops=red_diamond);

# %%
data = data_BM[['Item_Weight', 'Item_MRP']]
fig, ax = plt.subplots()
plt.xticks(ticks=[1,2], labels=['Item Weight', 'Item MRP'])
plt.violinplot(data.values);

# %%
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')
plt.scatter(data_BM["Item_Weight"][:200], data_BM["Item_Visibility"][:200]);

# %%
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.title('Item Outlet Sales vs Item MRP (price)')
plt.scatter(data_BM["Item_MRP"][:100], data_BM["Item_Outlet_Sales"][:100], s=data_BM["Item_Visibility"][:100]*1000, c='red');

# %%
# importing required libraries
import seaborn as sns
sns.set()
sns.set(style="darkgrid")


import numpy as np
import pandas as pd

# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize']=(10,10)

# %%
# read the dataset
data_BM = pd.read_csv('Data/bigmart_data.csv')
# drop the null values
data_BM = data_BM.dropna(how="any")
# multiply Item_Visibility by 100 to increase size
data_BM["Visibility_Scaled"] = data_BM["Item_Visibility"] * 100
# view the top results
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 4        High               Tier 3  Supermarket Type1           994.7052
# 5      Medium               Tier 3  Supermarket Type2           556.6088
#
#    Visibility_Scaled
# 0           1.604730
# 1           1.927822
# 2           1.676007
# 4           0.000000
# 5           0.000000

# %%
sns.lineplot(x="Item_Weight", y="Item_MRP",data=data_BM[:50]);

# %%
sns.barplot(x="Item_Type", y="Item_MRP", data=data_BM[:5])
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_MRP'>

# %%
sns.distplot(data_BM['Item_MRP'])
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Density'>

# %%
sns.boxplot(data_BM['Item_Outlet_Sales'], orient='vertical')
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %%
sns.violinplot(data_BM['Item_Outlet_Sales'], orient='vertical', color='magenta')
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %%
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", data=data_BM[:200], kind="scatter");

# %%
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", hue="Item_Type",data=data_BM[:200]);

# %%
sns.lineplot(x="Item_Weight", y="Item_MRP",hue='Outlet_Size',data=data_BM[:150]);

# %%
sns.relplot(x="Item_MRP", y="Item_Outlet_Sales", data=data_BM[:200], kind="scatter", size="Visibility_Scaled", hue="Visibility_Scaled");

# %%
sns.relplot(x="Item_Weight", y="Item_Visibility",hue='Outlet_Size',style='Outlet_Size',col='Outlet_Size',data=data_BM[:100]);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind='strip',data=data_BM[:250]);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales", kind='swarm',data=data_BM[:250]);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales",kind="box",data=data_BM);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales",kind="violin",data=data_BM);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales",kind="boxen",data=data_BM);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales",kind="point",data=data_BM);

# %%
sns.catplot(x="Outlet_Size", y="Item_Outlet_Sales",kind="bar",data=data_BM);

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(data_BM['Item_Visibility'], shade=True);

# %%
# distribution of Item MRP
plt.figure(figsize=(10,10))
sns.kdeplot(data_BM['Item_MRP'], shade=True);

# %%
plt.figure(figsize=(10,10))
sns.distplot(data_BM['Item_Outlet_Sales']);

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', height=2.5);

# %%
import pandas as pd

# %%
data=pd.read_csv('Data/train_bm.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
